# %%
import cv2
import numpy as np
import os
from matplotlib import pyplot as plt
import time
import mediapipe as mp

# %%
mp_holistic = mp.solutions.holistic  # Holistic model
mp_drawing = mp.solutions.drawing_utils  # Drawing utilities

def mediapipe_detection(image, model):
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)  # COLOR CONVERSION BGR 2 RGB
    image.flags.writeable = False  # Image is no longer writeable
    results = model.process(image)  # Make prediction
    image.flags.writeable = True  # Image is now writeable
    image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)  # COLOR CONVERSION RGB 2 BGR
    return image, results

def draw_landmarks(image, results):
    # Draw pose connections
    mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_holistic.POSE_CONNECTIONS)  # Draw pose connections
    # Draw left hand connections
    mp_drawing.draw_landmarks(image, results.left_hand_landmarks, mp_holistic.HAND_CONNECTIONS)  # Left hand
    # Draw right hand connections
    mp_drawing.draw_landmarks(image, results.right_hand_landmarks, mp_holistic.HAND_CONNECTIONS)  # Right hand
    # Draw face landmarks (use mp.solutions.face_mesh instead)
    if results.face_landmarks:
        mp_drawing.draw_landmarks(image, results.face_landmarks, mp.solutions.face_mesh.FACEMESH_CONTOURS)

def draw_styled_landmarks(image, results):
    # Draw face connections
    if results.face_landmarks:
        mp_drawing.draw_landmarks(
            image, results.face_landmarks, mp.solutions.face_mesh.FACEMESH_CONTOURS,
            mp_drawing.DrawingSpec(color=(80, 110, 10), thickness=1, circle_radius=1),
            mp_drawing.DrawingSpec(color=(80, 256, 121), thickness=1, circle_radius=1)
        )
    # Draw pose connections
    mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_holistic.POSE_CONNECTIONS,
                              mp_drawing.DrawingSpec(color=(80, 22, 10), thickness=2, circle_radius=4),
                              mp_drawing.DrawingSpec(color=(80, 44, 121), thickness=2, circle_radius=2))
    # Draw left hand connections
    mp_drawing.draw_landmarks(image, results.left_hand_landmarks, mp_holistic.HAND_CONNECTIONS,
                              mp_drawing.DrawingSpec(color=(121, 22, 76), thickness=2, circle_radius=4),
                              mp_drawing.DrawingSpec(color=(121, 44, 250), thickness=2, circle_radius=2))
    # Draw right hand connections
    mp_drawing.draw_landmarks(image, results.right_hand_landmarks, mp_holistic.HAND_CONNECTIONS,
                              mp_drawing.DrawingSpec(color=(245, 117, 66), thickness=2, circle_radius=4),
                              mp_drawing.DrawingSpec(color=(245, 66, 230), thickness=2, circle_radius=2))

cap = cv2.VideoCapture(0)

# Set the resolution (width x height)
cap.set(cv2.CAP_PROP_FRAME_WIDTH, 1000)  # Set width q
cap.set(cv2.CAP_PROP_FRAME_HEIGHT, 600)  # Set height 

# Set mediapipe model
with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
    while cap.isOpened():
        # Read feed
        ret, frame = cap.read()

        # Make detections
        image, results = mediapipe_detection(frame, holistic)
        print(results)
        
        # Draw landmarks
        draw_styled_landmarks(image, results)

        # Show to screen
        cv2.imshow('OpenCV Feed', image)

        # Break gracefully
        if cv2.waitKey(10) & 0xFF == ord('q'):
            break

cap.release()
cv2.destroyAllWindows()
# Out:
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>

# %%
# step 3
def extract_keypoints(results):
    """
    Extracts keypoint values from MediaPipe results for pose, face, and hands.
    Returns a single flattened array of keypoints.
    """
    # Extract pose landmarks
    pose = np.array([[res.x, res.y, res.z, res.visibility] for res in results.pose_landmarks.landmark]).flatten() \
        if results.pose_landmarks else np.zeros(33 * 4)

    # Extract face landmarks
    face = np.array([[res.x, res.y, res.z] for res in results.face_landmarks.landmark]).flatten() \
        if results.face_landmarks else np.zeros(468 * 3)

    # Extract left hand landmarks
    lh = np.array([[res.x, res.y, res.z] for res in results.left_hand_landmarks.landmark]).flatten() \
        if results.left_hand_landmarks else np.zeros(21 * 3)

    # Extract right hand landmarks
    rh = np.array([[res.x, res.y, res.z] for res in results.right_hand_landmarks.landmark]).flatten() \
        if results.right_hand_landmarks else np.zeros(21 * 3)

    # Concatenate all keypoints into a single array
    return np.concatenate([pose, face, lh, rh])

# Example usage
result_test = extract_keypoints(results)
print("Shape of extracted keypoints:", result_test.shape)
# Out:
# Shape of extracted keypoints: (1662,)

# %%
# step 4
# Path for exported data, numpy arrays
DATA_PATH = os.path.join('MP_Data')

# Actions that we try to detect
actions = np.array(['yes','no','burger','KFC''coke', 'Nescafe'])

# Number of videos worth of data
no_sequences = 40

# Videos are going to be 30 frames in length
sequence_length = 30

# Ensure base directory exists
if not os.path.exists(DATA_PATH):
    os.makedirs(DATA_PATH)

# Create directories for each action and sequence
for action in actions: 
    for sequence in range(no_sequences):
        path = os.path.join(DATA_PATH, action, str(sequence))
        try: 
            os.makedirs(path)
            print(f"Created folder: {path}")
        except FileExistsError:
            print(f"Folder already exists: {path}")
# Out:
# Folder already exists: MP_Data\coke\0
# Folder already exists: MP_Data\coke\1
# Folder already exists: MP_Data\coke\2
# Folder already exists: MP_Data\coke\3
# Folder already exists: MP_Data\coke\4
# Folder already exists: MP_Data\coke\5
# Folder already exists: MP_Data\coke\6
# Folder already exists: MP_Data\coke\7
# Folder already exists: MP_Data\coke\8
# Folder already exists: MP_Data\coke\9
# Folder already exists: MP_Data\coke\10
# Folder already exists: MP_Data\coke\11
# Folder already exists: MP_Data\coke\12
# Folder already exists: MP_Data\coke\13
# Folder already exists: MP_Data\coke\14
# Folder already exists: MP_Data\coke\15
# Folder already exists: MP_Data\coke\16
# Folder already exists: MP_Data\coke\17
# Folder already exists: MP_Data\coke\18
# Folder already exists: MP_Data\coke\19
# Folder already exists: MP_Data\coke\20
# Folder already exists: MP_Data\coke\21
# Folder already exists: MP_Data\coke\22
# Folder already exists: MP_Data\coke\23
# Folder already exists: MP_Data\coke\24
# Folder already exists: MP_Data\coke\25
# Folder already exists: MP_Data\coke\26
# Folder already exists: MP_Data\coke\27
# Folder already exists: MP_Data\coke\28
# Folder already exists: MP_Data\coke\29
# Folder already exists: MP_Data\coke\30
# Folder already exists: MP_Data\coke\31
# Folder already exists: MP_Data\coke\32
# Folder already exists: MP_Data\coke\33
# Folder already exists: MP_Data\coke\34
# Folder already exists: MP_Data\coke\35
# Folder already exists: MP_Data\coke\36
# Folder already exists: MP_Data\coke\37
# Folder already exists: MP_Data\coke\38
# Folder already exists: MP_Data\coke\39
# Folder already exists: MP_Data\Nescafe\0
# Folder already exists: MP_Data\Nescafe\1
# Folder already exists: MP_Data\Nescafe\2
# Folder already exists: MP_Data\Nescafe\3
# Folder already exists: MP_Data\Nescafe\4
# Folder already exists: MP_Data\Nescafe\5
# Folder already exists: MP_Data\Nescafe\6
# Folder already exists: MP_Data\Nescafe\7
# Folder already exists: MP_Data\Nescafe\8
# Folder already exists: MP_Data\Nescafe\9
# Folder already exists: MP_Data\Nescafe\10
# Folder already exists: MP_Data\Nescafe\11
# Folder already exists: MP_Data\Nescafe\12
# Folder already exists: MP_Data\Nescafe\13
# Folder already exists: MP_Data\Nescafe\14
# Folder already exists: MP_Data\Nescafe\15
# Folder already exists: MP_Data\Nescafe\16
# Folder already exists: MP_Data\Nescafe\17
# Folder already exists: MP_Data\Nescafe\18
# Folder already exists: MP_Data\Nescafe\19
# Folder already exists: MP_Data\Nescafe\20
# Folder already exists: MP_Data\Nescafe\21
# Folder already exists: MP_Data\Nescafe\22
# Folder already exists: MP_Data\Nescafe\23
# Folder already exists: MP_Data\Nescafe\24
# Folder already exists: MP_Data\Nescafe\25
# Folder already exists: MP_Data\Nescafe\26
# Folder already exists: MP_Data\Nescafe\27
# Folder already exists: MP_Data\Nescafe\28
# Folder already exists: MP_Data\Nescafe\29
# Folder already exists: MP_Data\Nescafe\30
# Folder already exists: MP_Data\Nescafe\31
# Folder already exists: MP_Data\Nescafe\32
# Folder already exists: MP_Data\Nescafe\33
# Folder already exists: MP_Data\Nescafe\34
# Folder already exists: MP_Data\Nescafe\35
# Folder already exists: MP_Data\Nescafe\36
# Folder already exists: MP_Data\Nescafe\37
# Folder already exists: MP_Data\Nescafe\38
# Folder already exists: MP_Data\Nescafe\39

# %%
#step 5, collect data, no need to run since alr collected
cap = cv2.VideoCapture(0)
# Set mediapipe model 
with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
    
    # NEW LOOP
    # Loop through actions
    for action in actions:
        # Loop through sequences aka videos
        for sequence in range(no_sequences):
            # Loop through video length aka sequence length
            for frame_num in range(sequence_length):

                # Read feed
                ret, frame = cap.read()

                # Make detections
                image, results = mediapipe_detection(frame, holistic)
#                 print(results)

                # Draw landmarks
                draw_styled_landmarks(image, results)
                
                # NEW Apply wait logic
                if frame_num == 0: 
                    cv2.putText(image, 'STARTING COLLECTION', (120,200), 
                               cv2.FONT_HERSHEY_SIMPLEX, 1, (0,255, 0), 4, cv2.LINE_AA)
                    cv2.putText(image, 'Collecting frames for {} Video Number {}'.format(action, sequence), (15,12), 
                               cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 255), 1, cv2.LINE_AA)
                    # Show to screen
                    cv2.imshow('OpenCV Feed', image)
                    cv2.waitKey(2000)
                else: 
                    cv2.putText(image, 'Collecting frames for {} Video Number {}'.format(action, sequence), (15,12), 
                               cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 255), 1, cv2.LINE_AA)
                    # Show to screen
                    cv2.imshow('OpenCV Feed', image)
                
                # NEW Export keypoints
                keypoints = extract_keypoints(results)
                npy_path = os.path.join(DATA_PATH, action, str(sequence), str(frame_num))
                np.save(npy_path, keypoints)

                # Break gracefully
                if cv2.waitKey(10) & 0xFF == ord('q'):
                    break
                    
    cap.release()
    cv2.destroyAllWindows()

# %%
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical

actions = ["burger", "yes", "no", "Nescafe","KFC","coke"]

# Map actions to numerical labels
label_map = {label: num for num, label in enumerate(actions)}

# Prepare sequences and labels
sequences, labels = [], []
for action in actions:
    for sequence in range(no_sequences):
        window = []
        for frame_num in range(sequence_length):
            res = np.load(os.path.join(DATA_PATH, action, str(sequence), "{}.npy".format(frame_num)))
            window.append(res)
        sequences.append(window)
        labels.append(label_map[action])

# Convert to numpy arrays
X = np.array(sequences)
y = to_categorical(labels).astype(int)

# Split data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.05)

print(f"Training data shape: {X_train.shape}, {y_train.shape}")
print(f"Testing data shape: {X_test.shape}, {y_test.shape}")
# Out:
# Training data shape: (228, 30, 1662), (228, 6)
# Testing data shape: (12, 30, 1662), (12, 6)

# %%
# training LSTM, no need to run this again
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from tensorflow.keras.callbacks import TensorBoard
from tensorflow.keras.callbacks import ReduceLROnPlateau
from tensorflow.keras.regularizers import l2
import time

# Create a TensorBoard callback
log_dir = os.path.join('Logs')
if not os.path.exists(log_dir):
    os.makedirs(log_dir)

tb_callback = TensorBoard(log_dir=log_dir)

# Define the model
model = Sequential([
    LSTM(64, return_sequences=True, activation='relu', input_shape=(30, X_train.shape[2]),kernel_regularizer=l2(0.01)),
    LSTM(128, return_sequences=True, activation='relu',kernel_regularizer=l2(0.01)),
    LSTM(64, return_sequences=False, activation='relu',kernel_regularizer=l2(0.01)),
    Dropout(0.3),
    Dense(64, activation='relu'),
    Dense(32, activation='relu'),
    Dense(6, activation='softmax')  # Output layer for classification
])

# Compile the model
model.compile(optimizer='Adam', loss='categorical_crossentropy', metrics=['categorical_accuracy'])

lr_scheduler = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=3, min_lr=0.0001)

# Train the model
model.fit(
    X_train, y_train,
    epochs=300,  # Use a reasonable number of epochs
    validation_data=(X_test, y_test),
    callbacks=[tb_callback]
)

model.save('test(YN)_action_model.h5')
# Out:
# Epoch 1/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━
300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 119ms/step - categorical_accuracy: 0.4348 - loss: 1.9011 - val_categorical_accuracy: 0.1667 - val_loss: 2.2193
# Epoch 31/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 115ms/step - categorical_accuracy: 0.3880 - loss: 1.8296 - val_categorical_accuracy: 0.0833 - val_loss: 2.2243
# Epoch 32/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 116ms/step - categorical_accuracy: 0.4371 - loss: 1.7379 - val_categorical_accuracy: 0.0833 - val_loss: 2.3369
# Epoch 33/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 116ms/step - categorical_accuracy: 0.3815 - loss: 1.7597 - val_categorical_accuracy: 0.3333 - val_loss: 1.9994
# Epoch 34/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 121ms/step - categorical_accuracy: 0.4149 - loss: 1.7812 - val_categorical_accuracy: 0.1667 - val_loss: 2.1502
# Epoch 35/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 124ms/step - categorical_accuracy: 0.4365 - loss: 1.6448 - val_categorical_accuracy: 0.5000 - val_loss: 1.8853
# Epoch 36/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 116ms/step - categorical_accuracy: 0.5204 - loss: 1.5848 - val_categorical_accuracy: 0.5833 - val_loss: 1.8198
# Epoch 37/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 114ms/step - categorical_accuracy: 0.5286 - loss: 1.5548 - val_categorical_accuracy: 0.5833 - val_loss: 1.8775
# Epoch 38/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 117ms/step - categorical_accuracy: 0.5730 - loss: 1.4722 - val_categorical_accuracy: 0.3333 - val_loss: 2.4474
# Epoch 39/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 123ms/step - categorical_accuracy: 0.4412 - loss: 1.7459 - val_categorical_accuracy: 0.2500 - val_loss: 1.9778
# Epoch 40/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 115ms/step - categorical_accuracy: 0.2929 - loss: 1.8225 - val_categorical_accuracy: 0.2500 - val_loss: 1.8467
# Epoch 41/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 116ms/step - categorical_accuracy: 0.4527 - loss: 1.6371 - val_categorical_accuracy: 0.4167 - val_loss: 1.8002
# Epoch 42/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 116ms/step - categorical_accuracy: 0.4200 - loss: 1.5714 - val_categorical_accuracy: 0.3333 - val_loss: 1.9277
# Epoch 43/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 111ms/step - categorical_accuracy: 0.4266 - loss: 1.6379 - val_categorical_accuracy: 0.3333 - val_loss: 1.7750
# Epoch 44/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 116ms/step - categorical_accuracy: 0.4681 - loss: 1.5090 - val_categorical_accuracy: 0.7500 - val_loss: 1.6617
# Epoch 45/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 118ms/step - categorical_accuracy: 0.4990 - loss: 1.4695 - val_categorical_accuracy: 0.6667 - val_loss: 1.7411
# Epoch 46/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 112ms/step - categorical_accuracy: 0.5497 - loss: 1.3453 - val_categorical_accuracy: 0.5833 - val_loss: 1.8564
# Epoch 47/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 117ms/step - categorical_accuracy: 0.5708 - loss: 1.2889 - val_categorical_accuracy: 0.2500 - val_loss: 2.6795
# Epoch 48/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 118ms/step - categorical_accuracy: 0.4825 - loss: 1.4631 - val_categorical_accuracy: 0.5833 - val_loss: 1.7640
# Epoch 49/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 111ms/step - categorical_accuracy: 0.5201 - loss: 1.4355 - val_categorical_accuracy: 0.5000 - val_loss: 2.0077
# Epoch 50/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 113ms/step - categorical_accuracy: 0.5271 - loss: 1.3690 - val_categorical_accuracy: 0.6667 - val_loss: 1.6054
# Epoch 51/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 110ms/step - categorical_accuracy: 0.6555 - loss: 1.2630 - val_categorical_accuracy: 0.6667 - val_loss: 1.6918
# Epoch 52/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 114ms/step - categorical_accuracy: 0.5953 - loss: 1.2431 - val_categorical_accuracy: 0.5833 - val_loss: 1.6833
# Epoch 53/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 114ms/step - categorical_accuracy: 0.7254 - loss: 1.0806 - val_categorical_accuracy: 0.5000 - val_loss: 2.2134
# Epoch 54/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 113ms/step - categorical_accuracy: 0.5943 - loss: 1.3979 - val_categorical_accuracy: 0.6667 - val_loss: 1.5830
# Epoch 55/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 114ms/step - categorical_accuracy: 0.6834 - loss: 1.1886 - val_categorical_accuracy: 0.5833 - val_loss: 1.5713
# Epoch 56/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 113ms/step - categorical_accuracy: 0.6927 - loss: 1.1140 - val_categorical_accuracy: 0.5833 - val_loss: 1.6886
# Epoch 57/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 116ms/step - categorical_accuracy: 0.6285 - loss: 1.1293 - val_categorical_accuracy: 0.5000 - val_loss: 2.0114
# Epoch 58/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 114ms/step - categorical_accuracy: 0.7187 - loss: 1.0357 - val_categorical_accuracy: 0.5833 - val_loss: 1.7307
# Epoch 59/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 114ms/step - categorical_accuracy: 0.7377 - loss: 0.9733 - val_categorical_accuracy: 0.5000 - val_loss: 1.9776
# Epoch 60/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 114ms/step - categorical_accuracy: 0
300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 119ms/step - categorical_accuracy: 0.3590 - loss: 1.9250 - val_categorical_accuracy: 0.2500 - val_loss: 1.8135
# Epoch 91/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 115ms/step - categorical_accuracy: 0.3400 - loss: 1.6985 - val_categorical_accuracy: 0.3333 - val_loss: 1.8586
# Epoch 92/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 121ms/step - categorical_accuracy: 0.4955 - loss: 1.4910 - val_categorical_accuracy: 0.2500 - val_loss: 1.8161
# Epoch 93/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 116ms/step - categorical_accuracy: 0.5903 - loss: 1.4867 - val_categorical_accuracy: 0.5000 - val_loss: 1.7937
# Epoch 94/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 114ms/step - categorical_accuracy: 0.4804 - loss: 1.4563 - val_categorical_accuracy: 0.4167 - val_loss: 1.7529
# Epoch 95/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 113ms/step - categorical_accuracy: 0.4515 - loss: 1.4533 - val_categorical_accuracy: 0.5000 - val_loss: 1.6370
# Epoch 96/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 118ms/step - categorical_accuracy: 0.5432 - loss: 1.3966 - val_categorical_accuracy: 0.5000 - val_loss: 1.8085
# Epoch 97/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 118ms/step - categorical_accuracy: 0.5553 - loss: 1.3394 - val_categorical_accuracy: 0.5833 - val_loss: 1.6872
# Epoch 98/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 114ms/step - categorical_accuracy: 0.5629 - loss: 1.3126 - val_categorical_accuracy: 0.5833 - val_loss: 1.6109
# Epoch 99/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 110ms/step - categorical_accuracy: 0.6432 - loss: 1.1824 - val_categorical_accuracy: 0.5833 - val_loss: 1.6354
# Epoch 100/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 113ms/step - categorical_accuracy: 0.5797 - loss: 1.1947 - val_categorical_accuracy: 0.5833 - val_loss: 2.1914
# Epoch 101/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 114ms/step - categorical_accuracy: 0.5824 - loss: 1.2108 - val_categorical_accuracy: 0.5000 - val_loss: 1.8803
# Epoch 102/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 113ms/step - categorical_accuracy: 0.6124 - loss: 1.2119 - val_categorical_accuracy: 0.6667 - val_loss: 1.5597
# Epoch 103/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 115ms/step - categorical_accuracy: 0.7009 - loss: 1.0077 - val_categorical_accuracy: 0.5000 - val_loss: 1.6614
# Epoch 104/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 110ms/step - categorical_accuracy: 0.6305 - loss: 1.2183 - val_categorical_accuracy: 0.5000 - val_loss: 1.5636
# Epoch 105/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 124ms/step - categorical_accuracy: 0.5325 - loss: 1.2125 - val_categorical_accuracy: 0.5833 - val_loss: 1.5139
# Epoch 106/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 128ms/step - categorical_accuracy: 0.6329 - loss: 1.0647 - val_categorical_accuracy: 0.5833 - val_loss: 1.4949
# Epoch 107/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 117ms/step - categorical_accuracy: 0.7239 - loss: 0.9326 - val_categorical_accuracy: 0.4167 - val_loss: 2.1475
# Epoch 108/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 121ms/step - categorical_accuracy: 0.5501 - loss: 1.2105 - val_categorical_accuracy: 0.5833 - val_loss: 1.8710
# Epoch 109/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 121ms/step - categorical_accuracy: 0.6921 - loss: 0.9687 - val_categorical_accuracy: 0.5000 - val_loss: 1.4948
# Epoch 110/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 114ms/step - categorical_accuracy: 0.6171 - loss: 0.9824 - val_categorical_accuracy: 0.6667 - val_loss: 2.1933
# Epoch 111/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 111ms/step - categorical_accuracy: 0.6596 - loss: 0.9879 - val_categorical_accuracy: 0.6667 - val_loss: 1.8601
# Epoch 112/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 113ms/step - categorical_accuracy: 0.6563 - loss: 0.9685 - val_categorical_accuracy: 0.6667 - val_loss: 1.4820
# Epoch 113/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 112ms/step - categorical_accuracy: 0.7106 - loss: 0.9362 - val_categorical_accuracy: 0.5833 - val_loss: 1.6402
# Epoch 114/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 117ms/step - categorical_accuracy: 0.7002 - loss: 1.0512 - val_categorical_accuracy: 0.5833 - val_loss: 1.8019
# Epoch 115/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 116ms/step - categorical_accuracy: 0.6599 - loss: 0.9840 - val_categorical_accuracy: 0.5833 - val_loss: 1.5328
# Epoch 116/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 113ms/step - categorical_accuracy: 0.7166 - loss: 0.9385 - val_categorical_accuracy: 0.5000 - val_loss: 1.6937
# Epoch 117/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 113ms/step - categorical_accuracy: 0.7925 - loss: 0.8118 - val_categorical_accuracy: 0.6667 - val_loss: 1.8086
# Epoch 118/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 114ms/step - categorical_accuracy: 0.7576 - loss: 0.7657 - val_categorical_accuracy: 0.6667 - val_loss: 2.0640
# Epoch 119/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 118ms/step - categorical_accuracy: 0
300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 117ms/step - categorical_accuracy: 0.8611 - loss: 0.5299 - val_categorical_accuracy: 0.9167 - val_loss: 0.6356
# Epoch 179/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 118ms/step - categorical_accuracy: 0.8940 - loss: 0.4791 - val_categorical_accuracy: 0.7500 - val_loss: 0.7094
# Epoch 180/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 120ms/step - categorical_accuracy: 0.9312 - loss: 0.3805 - val_categorical_accuracy: 0.9167 - val_loss: 0.5858
# Epoch 181/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 117ms/step - categorical_accuracy: 0.9249 - loss: 0.3967 - val_categorical_accuracy: 0.3333 - val_loss: 8.9021
# Epoch 182/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 118ms/step - categorical_accuracy: 0.4379 - loss: 18.6473 - val_categorical_accuracy: 0.1667 - val_loss: 1.7647
# Epoch 183/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 122ms/step - categorical_accuracy: 0.1861 - loss: 2.7473 - val_categorical_accuracy: 0.2500 - val_loss: 2.6692
# Epoch 184/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 113ms/step - categorical_accuracy: 0.2130 - loss: 10.7658 - val_categorical_accuracy: 0.1667 - val_loss: 2.5253
# Epoch 185/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 113ms/step - categorical_accuracy: 0.1414 - loss: 2.8044 - val_categorical_accuracy: 0.3333 - val_loss: 2.8980
# Epoch 186/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 111ms/step - categorical_accuracy: 0.2560 - loss: 3.0195 - val_categorical_accuracy: 0.1667 - val_loss: 3.2708
# Epoch 187/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 112ms/step - categorical_accuracy: 0.2792 - loss: 3.1982 - val_categorical_accuracy: 0.1667 - val_loss: 3.2522
# Epoch 188/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 110ms/step - categorical_accuracy: 0.2186 - loss: 3.2661 - val_categorical_accuracy: 0.1667 - val_loss: 3.1562
# Epoch 189/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 113ms/step - categorical_accuracy: 0.2325 - loss: 3.1580 - val_categorical_accuracy: 0.5000 - val_loss: 2.8924
# Epoch 190/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 114ms/step - categorical_accuracy: 0.3522 - loss: 3.0367 - val_categorical_accuracy: 0.2500 - val_loss: 3.0228
# Epoch 191/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 118ms/step - categorical_accuracy: 0.2492 - loss: 3.4854 - val_categorical_accuracy: 0.6667 - val_loss: 2.8051
# Epoch 192/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 115ms/step - categorical_accuracy: 0.2803 - loss: 3.0413 - val_categorical_accuracy: 0.1667 - val_loss: 2.9686
# Epoch 193/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 115ms/step - categorical_accuracy: 0.3228 - loss: 3.0141 - val_categorical_accuracy: 0.2500 - val_loss: 2.8489
# Epoch 194/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 111ms/step - categorical_accuracy: 0.3136 - loss: 2.9410 - val_categorical_accuracy: 0.2500 - val_loss: 2.7575
# Epoch 195/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 116ms/step - categorical_accuracy: 0.3187 - loss: 2.8295 - val_categorical_accuracy: 0.2500 - val_loss: 2.7225
# Epoch 196/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 110ms/step - categorical_accuracy: 0.3761 - loss: 2.6723 - val_categorical_accuracy: 0.3333 - val_loss: 2.6242
# Epoch 197/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 112ms/step - categorical_accuracy: 0.4566 - loss: 2.4912 - val_categorical_accuracy: 0.5000 - val_loss: 2.7464
# Epoch 198/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 113ms/step - categorical_accuracy: 0.3500 - loss: 2.6379 - val_categorical_accuracy: 0.4167 - val_loss: 2.3979
# Epoch 199/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 109ms/step - categorical_accuracy: 0.4202 - loss: 2.4742 - val_categorical_accuracy: 0.3333 - val_loss: 2.3800
# Epoch 200/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 113ms/step - categorical_accuracy: 0.4464 - loss: 2.4921 - val_categorical_accuracy: 0.4167 - val_loss: 3.2201
# Epoch 201/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 117ms/step - categorical_accuracy: 0.3261 - loss: 2.6795 - val_categorical_accuracy: 0.2500 - val_loss: 2.8671
# Epoch 202/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 111ms/step - categorical_accuracy: 0.1878 - loss: 3.3779 - val_categorical_accuracy: 0.5833 - val_loss: 2.8717
# Epoch 203/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 111ms/step - categorical_accuracy: 0.1645 - loss: 3.2436 - val_categorical_accuracy: 0.3333 - val_loss: 2.9206
# Epoch 204/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 120ms/step - categorical_accuracy: 0.2144 - loss: 3.0935 - val_categorical_accuracy: 0.2500 - val_loss: 2.9691
# Epoch 205/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 118ms/step - categorical_accuracy: 0.2037 - loss: 2.9877 - val_categorical_accuracy: 0.5000 - val_loss: 2.7717
# Epoch 206/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 112ms/step - categorical_accuracy: 0.2976 - loss: 2.8515 - val_categorical_accuracy: 0.1667 - val_loss: 3.9673
# Epoch 207/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 110ms/step - categorical_accuracy: 0.3103 - loss: 2.9418 - val_categorical_accuracy: 0.5000 - val_loss: 2.7418
# Epoch 208/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 111ms/step - categorical_accuracy: 0
300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 122ms/step - categorical_accuracy: 0.7188 - loss: 1.4638 - val_categorical_accuracy: 0.6667 - val_loss: 2.1960
# Epoch 267/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 120ms/step - categorical_accuracy: 0.6048 - loss: 1.8597 - val_categorical_accuracy: 0.4167 - val_loss: 2.0580
# Epoch 268/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 117ms/step - categorical_accuracy: 0.5757 - loss: 2.0718 - val_categorical_accuracy: 0.6667 - val_loss: 2.7259
# Epoch 269/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 126ms/step - categorical_accuracy: 0.6704 - loss: 1.5830 - val_categorical_accuracy: 0.8333 - val_loss: 1.7300
# Epoch 270/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 110ms/step - categorical_accuracy: 0.7428 - loss: 1.5514 - val_categorical_accuracy: 0.8333 - val_loss: 1.9692
# Epoch 271/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 113ms/step - categorical_accuracy: 0.7578 - loss: 1.4888 - val_categorical_accuracy: 0.8333 - val_loss: 1.6635
# Epoch 272/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 114ms/step - categorical_accuracy: 0.8286 - loss: 1.4334 - val_categorical_accuracy: 0.8333 - val_loss: 1.6695
# Epoch 273/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 113ms/step - categorical_accuracy: 0.7568 - loss: 1.4241 - val_categorical_accuracy: 0.7500 - val_loss: 1.5663
# Epoch 274/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 121ms/step - categorical_accuracy: 0.7182 - loss: 1.4399 - val_categorical_accuracy: 0.7500 - val_loss: 1.8273
# Epoch 275/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 114ms/step - categorical_accuracy: 0.7380 - loss: 1.4060 - val_categorical_accuracy: 0.6667 - val_loss: 2.1583
# Epoch 276/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 113ms/step - categorical_accuracy: 0.5421 - loss: 1.8504 - val_categorical_accuracy: 0.3333 - val_loss: 3.5601
# Epoch 277/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 110ms/step - categorical_accuracy: 0.4818 - loss: 2.1844 - val_categorical_accuracy: 0.8333 - val_loss: 1.7833
# Epoch 278/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 114ms/step - categorical_accuracy: 0.6938 - loss: 1.4631 - val_categorical_accuracy: 0.8333 - val_loss: 1.7962
# Epoch 279/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 111ms/step - categorical_accuracy: 0.7543 - loss: 1.4925 - val_categorical_accuracy: 0.7500 - val_loss: 2.0906
# Epoch 280/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 111ms/step - categorical_accuracy: 0.7348 - loss: 1.4824 - val_categorical_accuracy: 0.7500 - val_loss: 1.8322
# Epoch 281/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 118ms/step - categorical_accuracy: 0.7420 - loss: 1.4660 - val_categorical_accuracy: 0.7500 - val_loss: 1.6333
# Epoch 282/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 124ms/step - categorical_accuracy: 0.6743 - loss: 1.4820 - val_categorical_accuracy: 0.7500 - val_loss: 1.8172
# Epoch 283/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 118ms/step - categorical_accuracy: 0.7920 - loss: 1.3601 - val_categorical_accuracy: 0.8333 - val_loss: 2.0070
# Epoch 284/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 110ms/step - categorical_accuracy: 0.9033 - loss: 1.2605 - val_categorical_accuracy: 0.9167 - val_loss: 1.4198
# Epoch 285/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 115ms/step - categorical_accuracy: 0.8553 - loss: 1.2717 - val_categorical_accuracy: 0.9167 - val_loss: 1.3088
# Epoch 286/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 114ms/step - categorical_accuracy: 0.8529 - loss: 1.2193 - val_categorical_accuracy: 0.8333 - val_loss: 1.7300
# Epoch 287/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 115ms/step - categorical_accuracy: 0.7403 - loss: 1.5141 - val_categorical_accuracy: 0.9167 - val_loss: 1.1181
# Epoch 288/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 126ms/step - categorical_accuracy: 0.8615 - loss: 1.1701 - val_categorical_accuracy: 0.9167 - val_loss: 1.5066
# Epoch 289/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 119ms/step - categorical_accuracy: 0.8849 - loss: 1.1859 - val_categorical_accuracy: 0.7500 - val_loss: 1.9468
# Epoch 290/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 123ms/step - categorical_accuracy: 0.8407 - loss: 1.2371 - val_categorical_accuracy: 0.8333 - val_loss: 1.4714
# Epoch 291/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 124ms/step - categorical_accuracy: 0.9101 - loss: 1.1246 - val_categorical_accuracy: 0.7500 - val_loss: 1.7076
# Epoch 292/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 141ms/step - categorical_accuracy: 0.7216 - loss: 1.5443 - val_categorical_accuracy: 0.5000 - val_loss: 2.3788
# Epoch 293/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 115ms/step - categorical_accuracy: 0.7539 - loss: 1.5115 - val_categorical_accuracy: 0.6667 - val_loss: 2.2374
# Epoch 294/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 114ms/step - categorical_accuracy: 0.7602 - loss: 1.3945 - val_categorical_accuracy: 0.9167 - val_loss: 1.7144
# Epoch 295/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 116ms/step - categorical_accuracy: 0.7498 - loss: 1.3792 - val_categorical_accuracy: 0.7500 - val_loss: 1.7228
# Epoch 296/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 120ms/step - categorical_accuracy: 0.8167 - loss: 1.2708 - val_categorical_accuracy: 0.7500 - val_loss: 2.0211
# Epoch 297/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 116ms/step - categorical_accuracy: 0.8660 - loss: 1.1739 - val_categorical_accuracy: 0.8333 - val_loss: 1.7412
# Epoch 298/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 119ms/step - categorical_accuracy: 0.8932 - loss: 1.0996 - val_categorical_accuracy: 0.8333 - val_loss: 1.6761
# Epoch 299/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 113ms/step - categorical_accuracy: 0.9075 - loss: 1.0765 - val_categorical_accuracy: 0.7500 - val_loss: 1.7025
# Epoch 300/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 113ms/step - categorical_accuracy: 0.8766 - loss: 1.1405 - val_categorical_accuracy: 0.8333 - val_loss: 1.6765
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
model.evaluate(X_test, y_test)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step - categorical_accuracy: 0.8333 - loss: 1.6765
# [1.676526427268982, 0.8333333134651184]

# %%
#reloading model
from tensorflow.keras.models import load_model
model = load_model('test(YN)_action_model.h5')
#You can now use this model to evaluate or predict without retraining.
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %%
#switch X_train to X_test and y_train to y_test if you want
from sklearn.metrics import multilabel_confusion_matrix
yhat = model.predict(X_test)
ytrue = np.argmax(y_test, axis=1).tolist()
yhat = np.argmax(yhat, axis=1).tolist()
multilabel_confusion_matrix(ytrue, yhat)
# Out:
# WARNING:tensorflow:5 out of the last 5 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x000002B9080E5AF0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:5 out of the last 5 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x000002B9080E5AF0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 998ms/step
# array([[[11,  0],
#         [ 0,  1]],
#
#        [[ 9,  1],
#         [ 0,  2]],
#
#        [[ 5,  0],
#         [ 2,  5]],
#
#        [[ 9,  1],
#         [ 0,  2]]], dtype=int64)

# %%
# yes, no control and send output to Gui
import cv2
import mediapipe as mp
import numpy as np
from tensorflow.keras.models import load_model

# Load trained model
model = load_model('test(YN)_action_model.h5')

# Mediapipe initialization
mp_holistic = mp.solutions.holistic
mp_drawing = mp.solutions.drawing_utils

# Actions and variables
actions = ["burger", "yes", "no", "KFC","Nescafe","coke"]
sequence = []
sentence = []
threshold = 0.8

# Visualization helper
def prob_viz(res, actions, input_frame, colors):
    output_frame = input_frame.copy()
    for num, prob in enumerate(res):
        cv2.rectangle(output_frame, (0, 60 + num * 40), (int(prob * 100), 90 + num * 40), colors[num], -1)
        cv2.putText(output_frame, actions[num], (0, 85 + num * 40), cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2, cv2.LINE_AA)
    return output_frame

# Detection loop
cap = cv2.VideoCapture(0)
action_images = {
    "burger": "C:/Users/YUANJIE/OneDrive - International Islamic University Malaysia/Documents/machinevision/uma_cv_2024-main/uma_cv_2024-main/hand sign detection/burgermv.jpg",
    "coke": "C:/Users/YUANJIE/OneDrive - International Islamic University Malaysia/Documents/machinevision/uma_cv_2024-main/uma_cv_2024-main/hand sign detection/cokemv.jpg",
    "Nescafe": "C:/Users/YUANJIE/OneDrive - International Islamic University Malaysia/Documents/machinevision/uma_cv_2024-main/uma_cv_2024-main/hand sign detection/nescafemvv.jpg",
    "KFC": "C:/Users/YUANJIE/OneDrive - International Islamic University Malaysia/Documents/machinevision/uma_cv_2024-main/uma_cv_2024-main/hand sign detection/kfcmvv.jpg",
    
}
colors = [(245, 117, 16), (117, 245, 16), (16, 117, 245), (102, 145, 147),(23,200,87),(142,160,178),(231,40,120),(50,245,30)]

with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
    while cap.isOpened():
        ret, frame = cap.read()
        if not ret:
            break

        frame = cv2.flip(frame, 1)
        image, results = mediapipe_detection(frame, holistic)

        draw_styled_landmarks(image, results)

        # Prediction logic
        keypoints = extract_keypoints(results)
        sequence.append(keypoints)
        sequence = sequence[-30:]

        if len(sequence) == 30:
            res = model.predict(np.expand_dims(sequence, axis=0))[0]
            detected_action = actions[np.argmax(res)]
            print(f"Detected action: {detected_action}")

            if detected_action == "yes" and res[np.argmax(res)] > threshold:
                print("Order completed. Exiting...")
                break
            elif detected_action == "no" and res[np.argmax(res)] > threshold:
                if sentence:
                    removed = sentence.pop()
                    print(f"Removed: {removed}")
            elif detected_action not in ["yes", "no"] and res[np.argmax(res)] > threshold:
                if not sentence or detected_action != sentence[-1]:
                    sentence.append(detected_action)
                    print(f"Added: {detected_action}")

            if len(sentence) > 5:
                sentence = sentence[-5:]

            # Save order to file
            with open('order_list.txt', 'w') as f:
                for item in sentence:
                    f.write(f"{item}\n")

            # Visualize probabilities
            image = prob_viz(res, actions, image, colors)

            # Display the image corresponding to the top action
            if detected_action in action_images:
                action_image = cv2.imread(action_images[detected_action])
                if action_image is not None:
                    action_image = cv2.resize(action_image, (100, 100))  # Resize to fit the corner
                    image[50:150, -110:-10] = action_image  # Position the image at top-right corner

        # Display current sentence
        cv2.rectangle(image, (0, 0), (640, 40), (245, 117, 16), -1)
        cv2.putText(image, ' '.join(sentence), (3, 30), cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2, cv2.LINE_AA)

        cv2.imshow('OpenCV Feed', image)

        if cv2.waitKey(10) & 0xFF == ord('q'):
            break

    cap.release()
    cv2.destroyAllWindows()
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:6 out of the last 6 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x000002B970378790> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 6 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x000002B970378790> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 806ms/step
# Detected action: Nescafe
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step
# Detected action: Nescafe
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# Detected action: Nescafe
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# Detected action: Nescafe
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# Detected action: Nescafe
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step
# Detected action: burger
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# Detected action: burger
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# Detected action: burger
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step
# Detected action: burger
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# Detected action: burger
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# Detected action: burger
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# Detected action: burger
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# Detected action: burger
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# Detected action: burger
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# Detected action: burger
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# Detected action: burger
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# Detected action: burger
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# Detected action: burger
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# Detected action: burger
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# Detected action: burger
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# Detected action: burger
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# Detected action: burger
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step
# Detected action: burger
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# Detected action: burger
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# Detected action: Nescafe
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# Detected action: Nescafe
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# Detected action: Nescafe
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# Detected action: Nescafe
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# Detected action: Nescafe
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# Detected action: Nescafe
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# Detected action: Nescafe
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# Detected action: Nescafe
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# Detected action: Nescafe
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# Detected action: burger
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# Detected action: burger
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# Detected action: burger
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# Detected action: burger
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# Detected action: burger
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# Detected action: burger
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# Detected action: burger
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# Detected action: burger
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# Detected action: burger
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# Detected action: burger
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# Detected action: burger
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# Detected action: burger
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# Detected action: burger
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# Detected action: burger
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# Detected action: burger
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# Detected action: burger
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# Detected action: burger
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# Detected action: burger
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step
# Detected action: burger
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# Detected action: burger
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# Detected action: burger
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step
# Detected action: burger
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# Detected action: burger
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# Detected action: burger
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# Detected action: burger
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# Detected action: burger
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# Detected action: burger
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# Detected action: burger
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# Detected action: burger
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# Detected action: burger
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step
# Detected action: burger
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# Detected action: burger
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# Detected action: burger
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# Detected action: burger
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# Detected action: burger
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# Detected action: burger
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# Detected action: burger
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# Detected action: burger
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# Detected action: burger
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# Detected action: Nescafe
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# Detected action: Nescafe
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# Detected action: Nescafe
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# Detected action: Nescafe
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# Detected action: Nescafe
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# Detected action: Nescafe
# Added: Nescafe
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# Detected action: Nescafe
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# Detected action: Nescafe
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# Detected action: Nescafe
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# Detected action: Nescafe
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# Detected action: Nescafe
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# Detected action: Nescafe
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# Detected action: Nescafe
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# Detected action: Nescafe
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# Detected action: Nescafe
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# Detected action: Nescafe
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# Detected action: Nescafe
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# Detected action: Nescafe
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# Detected action: Nescafe
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# Detected action: Nescafe
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# Detected action: Nescafe
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# Detected action: Nescafe
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# Detected action: Nescafe
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# Detected action: Nescafe
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# Detected action: Nescafe
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# Detected action: Nescafe
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# Detected action: Nescafe
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# Detected action: Nescafe
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# Detected action: Nescafe
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# Detected action: Nescafe
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# Detected action: Nescafe
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# Detected action: Nescafe
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# Detected action: Nescafe
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# Detected action: Nescafe
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# Detected action: Nescafe
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# Detected action: Nescafe
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# Detected action: Nescafe
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# Detected action: Nescafe
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# Detected action: Nescafe
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# Detected action: Nescafe
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# Detected action: Nescafe
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# Detected action: Nescafe
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# Detected action: Nescafe
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# Detected action: Nescafe
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# Detected action: burger
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# Detected action: burger
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# Detected action: burger
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# Detected action: burger
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# Detected action: Nescafe
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# Detected action: Nescafe
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# Detected action: burger
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# Detected action: burger
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step
# Detected action: burger
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# Detected action: burger
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# Detected action: burger
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# Detected action: Nescafe
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# Detected action: Nescafe
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# Detected action: Nescafe
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# Detected action: Nescafe
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# Detected action: Nescafe
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# Detected action: Nescafe
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# Detected action: Nescafe
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# Detected action: Nescafe
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# Detected action: Nescafe
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# Detected action: Nescafe
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# Detected action: Nescafe
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# Detected action: Nescafe
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# Detected action: Nescafe
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# Detected action: Nescafe
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# Detected action: Nescafe
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# Detected action: Nescafe
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# Detected action: Nescafe
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# Detected action: Nescafe
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# Detected action: Nescafe
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# Detected action: burger
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# Detected action: burger
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# Detected action: burger
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# Detected action: burger
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step
# Detected action: burger
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# Detected action: burger
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# Detected action: burger
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# Detected action: burger
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# Detected action: KFC
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# Detected action: KFC
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# Detected action: KFC
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# Detected action: KFC
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# Detected action: KFC
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# Detected action: KFC
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# Detected action: KFC
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# Detected action: KFC
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# Detected action: KFC
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# Detected action: KFC
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# Detected action: no
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# Detected action: no
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# Detected action: no
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# Detected action: no
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# Detected action: no
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# Detected action: no
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# Detected action: no
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# Detected action: coke
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# Detected action: coke
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# Detected action: coke
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# Detected action: no
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# Detected action: no
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# Detected action: no
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# Detected action: coke
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# Detected action: coke
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# Detected action: coke
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# Detected action: coke
# Added: coke
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# Detected action: coke
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# Detected action: coke
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# Detected action: coke
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# Detected action: coke
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# Detected action: coke
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# Detected action: coke
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# Detected action: no
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# Detected action: no
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# Detected action: KFC
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# Detected action: KFC
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# Detected action: KFC
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# Detected action: KFC
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# Detected action: KFC
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# Detected action: KFC
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# Detected action: KFC
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# Detected action: KFC
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# Detected action: KFC
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# Detected action: KFC
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step
# Detected action: KFC
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# Detected action: KFC
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# Detected action: KFC
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# Detected action: KFC
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# Detected action: KFC
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# Detected action: KFC
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# Detected action: KFC
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# Detected action: KFC
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# Detected action: KFC
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# Detected action: KFC
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# Detected action: KFC
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# Detected action: KFC
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step
# Detected action: KFC
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# Detected action: KFC
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# Detected action: KFC
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# Detected action: KFC
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# Detected action: KFC
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# Detected action: KFC
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# Detected action: KFC
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# Detected action: KFC
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# Detected action: KFC
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# Detected action: KFC
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# Detected action: KFC
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# Detected action: KFC
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# Detected action: KFC
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# Detected action: KFC
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# Detected action: KFC
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# Detected action: KFC
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# Detected action: KFC
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# Detected action: KFC
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# Detected action: KFC
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# Detected action: KFC
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# Detected action: KFC
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# Detected action: KFC
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# Detected action: KFC
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# Detected action: KFC
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# Detected action: KFC
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# Detected action: KFC
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# Detected action: KFC
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# Detected action: KFC
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# Detected action: KFC
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# Detected action: KFC
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# Detected action: KFC
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# Detected action: KFC
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# Detected action: KFC
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# Detected action: KFC
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# Detected action: KFC
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# Detected action: KFC
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# Detected action: KFC
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# Detected action: KFC
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# Detected action: KFC
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# Detected action: KFC
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# Detected action: KFC
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# Detected action: KFC
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# Detected action: KFC
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# Detected action: KFC
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# Detected action: KFC
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# Detected action: no
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# Detected action: no
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# Detected action: no
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# Detected action: no
# Removed: coke
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# Detected action: no
# Removed: Nescafe
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# Detected action: no
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# Detected action: no
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# Detected action: no
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# Detected action: no
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# Detected action: no
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# Detected action: no
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# Detected action: no
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# Detected action: no
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# Detected action: no
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# Detected action: no
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# Detected action: no
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# Detected action: no
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# Detected action: no
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# Detected action: no
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# Detected action: no
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# Detected action: no
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step
# Detected action: no
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# Detected action: no
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# Detected action: coke
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# Detected action: coke
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# Detected action: coke
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# Detected action: coke
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# Detected action: coke
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# Detected action: coke
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# Detected action: coke
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# Detected action: coke
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# Detected action: coke
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# Detected action: coke
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# Detected action: no
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# Detected action: no
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# Detected action: no
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# Detected action: no
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# Detected action: KFC
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# Detected action: KFC
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# Detected action: KFC
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# Detected action: KFC
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# Detected action: KFC
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# Detected action: KFC
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# Detected action: KFC
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# Detected action: KFC
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# Detected action: KFC
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# Detected action: burger
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# Detected action: Nescafe
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# Detected action: Nescafe
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# Detected action: Nescafe
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# Detected action: Nescafe
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# Detected action: Nescafe
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# Detected action: Nescafe
# Added: Nescafe
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# Detected action: Nescafe
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# Detected action: Nescafe
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# Detected action: Nescafe
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# Detected action: Nescafe
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# Detected action: Nescafe
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# Detected action: Nescafe
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# Detected action: Nescafe
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# Detected action: Nescafe
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# Detected action: Nescafe
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# Detected action: Nescafe
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# Detected action: Nescafe
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# Detected action: Nescafe
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# Detected action: Nescafe
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# Detected action: Nescafe
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# Detected action: Nescafe
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step
# Detected action: Nescafe
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# Detected action: Nescafe
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# Detected action: Nescafe
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# Detected action: Nescafe
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# Detected action: Nescafe
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# Detected action: Nescafe
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# Detected action: Nescafe
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# Detected action: Nescafe
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# Detected action: Nescafe
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# Detected action: burger
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# Detected action: burger
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# Detected action: burger
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# Detected action: burger
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# Detected action: burger
# Added: burger
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# Detected action: burger
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# Detected action: burger
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# Detected action: burger
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# Detected action: burger
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# Detected action: burger
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# Detected action: KFC
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# Detected action: KFC
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# Detected action: no
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# Detected action: no
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# Detected action: no
# Removed: burger
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# Detected action: no
# Removed: Nescafe
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# Detected action: no
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# Detected action: no
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# Detected action: no
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# Detected action: no
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# Detected action: no
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# Detected action: no
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# Detected action: no
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# Detected action: no
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# Detected action: no
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# Detected action: no
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# Detected action: no
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# Detected action: no
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# Detected action: no
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# Detected action: no
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# Detected action: no
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# Detected action: no
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# Detected action: no
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# Detected action: no
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# Detected action: no
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# Detected action: no
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# Detected action: no
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# Detected action: no
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# Detected action: no
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# Detected action: no
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# Detected action: no
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# Detected action: no
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# Detected action: no
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# Detected action: KFC
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# Detected action: KFC
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# Detected action: KFC
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# Detected action: KFC
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# Detected action: KFC
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# Detected action: KFC
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# Detected action: KFC
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# Detected action: KFC
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# Detected action: KFC
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# Detected action: KFC
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# Detected action: no
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# Detected action: no
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# Detected action: no
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# Detected action: no
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# Detected action: no
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# Detected action: no
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# Detected action: no
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# Detected action: no
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# Detected action: no
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# Detected action: no
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# Detected action: no
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# Detected action: no
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# Detected action: no
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# Detected action: no
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# Detected action: coke
# Added: coke

# %%
import tkinter as tk

def update_order_display():
    try:
        with open('order_list.txt', 'r') as f:
            items = f.readlines()
        order_var.set("\n".join(item.strip() for item in items))
    except FileNotFoundError:
        order_var.set("No items detected yet.")

    root.after(1000, update_order_display)

# Tkinter GUI setup
root = tk.Tk()
root.title("Order List")
root.geometry("300x300")

order_var = tk.StringVar()
label = tk.Label(root, textvariable=order_var, font=("Helvetica", 14), justify="left")
label.pack(pady=20)

update_order_display()
root.mainloop()

# %%
# ROBOFLOW data
import cv2
from ultralytics import YOLO
import numpy as np
import time
import random

# Load the YOLO model
model = YOLO("projectmv.pt")

# Actions and variables
sentence = []
general_threshold = 0.6
yes_no_threshold = 0.8  # Updated threshold for "yes" and "no" actions

# Action images (update these paths as needed)
action_images = {
    "Burger": "C:/Users/hp/Downloads/uma_cv_2024-main/uma_cv_2024-main/Projectmv/burgermv.jpg",
    "coke": "C:/Users/hp/Downloads/uma_cv_2024-main/uma_cv_2024-main/Projectmv/cokemv.jpg",
    "Nescafe": "C:/Users/hp/Downloads/uma_cv_2024-main/uma_cv_2024-main/Projectmv/nescafemvv.jpg",
    "KFC": "C:/Users/hp/Downloads/uma_cv_2024-main/uma_cv_2024-main/Projectmv/kfcmvv.jpg",
    "Curry": "C:/Users/hp/Downloads/uma_cv_2024-main/uma_cv_2024-main/Projectmv/currymv.jpg",
}

# Function to generate random colors
def generate_colors(n):
    return [(random.randint(0, 255), random.randint(0, 255), random.randint(0, 255)) for _ in range(n)]

# Visualization helper function
def prob_viz(res, actions, input_frame, colors):
    output_frame = input_frame.copy()
    for num, prob in enumerate(res):
        color = colors[num] if num < len(colors) else (0, 0, 0)  # Default to black if colors are exhausted
        cv2.rectangle(output_frame, (0, 60 + num * 40), (int(prob * 100), 90 + num * 40), color, -1)
        cv2.putText(output_frame, actions[num], (0, 85 + num * 40), cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2, cv2.LINE_AA)
    return output_frame

# Open video capture
cap = cv2.VideoCapture(0)

# Set video capture resolution (resize window)
cap.set(cv2.CAP_PROP_FRAME_WIDTH, 640)  # Width 1024px
cap.set(cv2.CAP_PROP_FRAME_HEIGHT, 480)  # Height 768px

while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        break

    results = model(frame, stream=True)

    for result in results:
        boxes = result.boxes

        # Check if boxes are empty or not
        if len(boxes) > 0:
            for bbox in boxes:
                x1, y1, x2, y2 = bbox.xyxy[0]
                x1, y1, x2, y2 = int(x1), int(y1), int(x2), int(y2)

                cls_idx = int(bbox.cls[0])
                cls_name = model.names[cls_idx]
                confidence = bbox.conf[0]

                print(f"Detected: {cls_name} with confidence: {confidence}")  # Debugging line

                # Draw bounding box and label
                cv2.rectangle(frame, (x1, y1), (x2, y2), (255, 0, 255), 4)
                cv2.putText(frame, cls_name, (x1, y1 - 5), cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 0, 0), 2)

                # Handle detected actions
                if cls_name in ["yes", "no"] and confidence > yes_no_threshold:
                    if cls_name == "yes":
                        print("Order completed. Saving and exiting...")
                        with open("order_list.txt", "w") as file:
                            for item in sentence:
                                file.write(f"{item}\n")
                        cap.release()
                        cv2.destroyAllWindows()
                        exit()
                    elif cls_name == "no" and sentence:
                        print("Detected 'no'. Immediately removing the last item...")
                        removed = sentence.pop()
                        print(f"Removed: {removed}")
                elif cls_name not in ["yes", "no"] and confidence > general_threshold:
                    if not sentence or cls_name != sentence[-1]:
                        sentence.append(cls_name)

                # Display action images if detected
                if cls_name in action_images:
                    print(f"Displaying image for: {cls_name}")  # Debugging line
                    action_image = cv2.imread(action_images[cls_name])
                    if action_image is not None:
                        action_image = cv2.resize(action_image, (100, 100))  # Resize to fit the corner
                        frame[50:150, -110:-10] = action_image  # Position the image at top-right corner
                    else:
                        print(f"Image for {cls_name} not found!")  # Debugging line

    # Generate a list of random colors based on sentence length
    colors = generate_colors(len(sentence))

    # Display sentence on the frame
    cv2.rectangle(frame, (0, 0), (1024, 40), (0, 0, 0), -1)  # Adjust rectangle for sentence display
    cv2.putText(frame, " ".join(sentence), (3, 30), cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2, cv2.LINE_AA)

    # Visualize the action probabilities (if needed)
    frame = prob_viz([1] * len(sentence), sentence, frame, colors)

    # Show the frame with detection and action images
    cv2.imshow("YOLO Detection", frame)

    if cv2.waitKey(1) & 0xFF == ord("q"):
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# 0: 480x640 (no detections), 354.5ms
# Speed: 10.9ms preprocess, 354.5ms inference, 3.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 329.9ms
# Speed: 4.0ms preprocess, 329.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 309.1ms
# Speed: 4.0ms preprocess, 309.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 307.1ms
# Speed: 2.0ms preprocess, 307.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 262.9ms
# Speed: 2.6ms preprocess, 262.9ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 262.2ms
# Speed: 3.0ms preprocess, 262.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 251.3ms
# Speed: 2.4ms preprocess, 251.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 253.3ms
# Speed: 3.0ms preprocess, 253.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 249.9ms
# Speed: 2.0ms preprocess, 249.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 244.1ms
# Speed: 3.3ms preprocess, 244.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 254.3ms
# Speed: 3.4ms preprocess, 254.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 243.7ms
# Speed: 4.0ms preprocess, 243.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 238.7ms
# Speed: 4.0ms preprocess, 238.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 242.1ms
# Speed: 3.5ms preprocess, 242.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 KFC, 248.9ms
# Detected: KFC with confidence: 0.6973502039909363
# Displaying image for: KFC
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[22], line 92
#      90 if cls_name in action_images:
#      91     print(f"Displaying image for: {cls_name}")  # Debugging line
# ---> 92     action_image = cv2.imread(action_images[cls_name])
#      93     if action_image is not None:
#      94         action_image = cv2.resize(action_image, (100, 100))  # Resize to fit the corner
#
# File c:\Users\YUANJIE\anaconda3\envs\Hsign\lib\site-packages\ultralytics\utils\patches.py:26, in imread(filename, flags)
#      15 def imread(filename: str, flags: int = cv2.IMREAD_COLOR):
#      16     """
#      17     Read an image from a file.
#      18
#    (...)
#      24         (np.ndarray): The read image.
#      25     """
# ---> 26     return cv2.imdecode(np.fromfile(filename, np.uint8), flags)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'C:/Users/hp/Downloads/uma_cv_2024-main/uma_cv_2024-main/Projectmv/kfcmvv.jpg'
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
import tkinter as tk

def update_order_display():
    try:
        with open('order_list.txt', 'r') as f:
            items = f.readlines()
        order_var.set("\n".join(item.strip() for item in items))
    except FileNotFoundError:
        order_var.set("No items detected yet.")

    root.after(1000, update_order_display)

# Tkinter GUI setup
root = tk.Tk()
root.title("Order List")
root.geometry("300x300")

order_var = tk.StringVar()
label = tk.Label(root, textvariable=order_var, font=("Helvetica", 14), justify="left")
label.pack(pady=20)

update_order_display()
root.mainloop()

# %%
# basic code to show performance
colors = [(245,117,16), (117,245,16), (16,117,245), (102,145,147)]
def prob_viz(res, actions, input_frame, colors):
    output_frame = input_frame.copy()
    for num, prob in enumerate(res):
        cv2.rectangle(output_frame, (0,60+num*40), (int(prob*100), 90+num*40), colors[num], -1)
        cv2.putText(output_frame, actions[num], (0, 85+num*40), cv2.FONT_HERSHEY_SIMPLEX, 1, (255,255,255), 2, cv2.LINE_AA)
        
    return output_frame

# 1. New detection variables
sequence = []
sentence = []
threshold = 0.9

cap = cv2.VideoCapture(0)
# Set mediapipe model 
with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
    while cap.isOpened():

        # Read feed
        ret, frame = cap.read()

        # Make detections
        image, results = mediapipe_detection(frame, holistic)
        print(results)
        
        # Draw landmarks
        draw_styled_landmarks(image, results)
        
        # 2. Prediction logic
        keypoints = extract_keypoints(results)
#         sequence.insert(0,keypoints)
#         sequence = sequence[:30]
        sequence.append(keypoints)
        sequence = sequence[-30:]
        
        if len(sequence) == 30:
            res = model.predict(np.expand_dims(sequence, axis=0))[0]
            print(actions[np.argmax(res)])
            
            
        #3. Viz logic
            if res[np.argmax(res)] > threshold: 
                if len(sentence) > 0: 
                    if actions[np.argmax(res)] != sentence[-1]:
                        sentence.append(actions[np.argmax(res)])
                else:
                    sentence.append(actions[np.argmax(res)])

            if len(sentence) > 5: 
                sentence = sentence[-5:]

            # Viz probabilities
            image = prob_viz(res, actions, image, colors)
            
        cv2.rectangle(image, (0,0), (640, 40), (245, 117, 16), -1)
        cv2.putText(image, ' '.join(sentence), (3,30), 
                       cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2, cv2.LINE_AA)
        
        # Show to screen
        cv2.imshow('OpenCV Feed', image)

        # Break gracefully
        if cv2.waitKey(10) & 0xFF == ord('q'):
            break
    cap.release()
    cv2.destroyAllWindows()
# Out:
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# yes
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# yes
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# yes
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# yes
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# yes
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# yes
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# yes
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# yes
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# yes
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# yes
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# yes
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# yes
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# yes
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# yes
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# yes
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# yes
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# yes
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# yes
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# yes
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# yes
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# yes
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# yes
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# yes
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# yes
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step
# yes
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# yes
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# yes
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# yes
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# yes
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# yes
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# yes
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# yes
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# yes
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# yes
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# yes
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# yes
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# yes
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# yes
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# yes
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# yes
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# yes
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# yes
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# yes
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# yes
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# yes
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# yes
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# yes
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# yes
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# yes
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# yes
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# yes
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# yes
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# yes
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# yes
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# yes
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# yes
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# yes
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# yes
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# yes
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# yes
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# yes
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# yes
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# yes
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# yes
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# yes
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# yes
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# yes
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# yes
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# yes
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# yes
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# yes
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# yes
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# yes
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# yes
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# yes
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# yes
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# yes
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# yes
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step
# yes
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# yes
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# yes
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# yes
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# yes
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# yes
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# yes
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# yes
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# yes
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# yes
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# yes
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# yes
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# yes
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# yes
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# yes
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# yes
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# yes
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# yes
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# yes
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# yes
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# yes
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# yes
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# yes
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# yes
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# no
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# no
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# no
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# no
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# no
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# curry
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# curry
